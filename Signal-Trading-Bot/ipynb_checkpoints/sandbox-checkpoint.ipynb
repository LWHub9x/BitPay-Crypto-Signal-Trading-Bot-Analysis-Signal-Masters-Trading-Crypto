# %%
import src.settings as settings
settings.init()
config_values = settings.config_values
historical_data = settings.historical_data
train_data = settings.train_data
test_data = settings.test_data
returns = settings.returns

import yaml
import warnings
warnings.filterwarnings('ignore')
from src.data_collection import collect_coins_data, load_data
from src.signals_creation import compute_signal, get_returns_data, get_rsi
from src.signals_evaluation import compute_metrics
from src.normalizations import convert_to_weights
from src.visualisation import plot_pnl
from src.settings import get_config_values
from src.signals_optimization import optimize_signal

# %%
rsi_params = config_values["signals_parameters"]["default"]["rsi"]
signal = compute_signal("rsi",train_data,**rsi_params)
returns = get_returns_data(train_data)
metrics = compute_metrics(signal, returns)
metrics
# Out:
# {'sharpe_ratio': -0.5337157649369455,
#  'annual_benefit': -19.090346800024633,
#  'daily_benefit': -0.05230232000006749,
#  'daily_turnover': 15.538438790338287,
#  'daily_pnl': -0.041425412846830684,
#  'pnl_series': timestamp
#  2019-09-08 02:00:00    0.000000
#  2019-09-09 02:00:00    0.000000
#  2019-09-10 02:00:00    0.000000
#  2019-09-11 02:00:00    0.000000
#  2019-09-12 02:00:00    0.000000
#                           ...
#  2022-09-19 02:00:00   -0.016495
#  2022-09-20 02:00:00    0.406240
#  2022-09-21 02:00:00    0.251661
#  2022-09-22 02:00:00    0.925446
#  2022-09-23 02:00:00    0.822331
#  Length: 1112, dtype: float64,
#  'turnover_series': timestamp
#  2019-09-08 02:00:00     0.000000
#  2019-09-09 02:00:00     0.000000
#  2019-09-10 02:00:00     0.000000
#  2019-09-11 02:00:00     0.000000
#  2019-09-12 02:00:00     0.000000
#                           ...
#  2022-09-19 02:00:00    19.685651
#  2022-09-20 02:00:00    23.878899
#  2022-09-21 02:00:00    20.022552
#  2022-09-22 02:00:00    17.159189
#  2022-09-23 02:00:00    24.757834
#  Length: 1112, dtype: float64}

# %%
study = optimize_signal()
# Out:
# [I 2023-07-02 17:36:33,848] A new study created in memory with name: no-name-e623b783-3401-424d-891e-19d5d6779e9c
# [I 2023-07-02 17:36:34,394] Trial 0 finished with value: -0.429840122851624 and parameters: {'lag': 1, 'normalization_choice': 2, 'window': 10}. Best is trial 0 with value: -0.429840122851624.
# [I 2023-07-02 17:36:38,860] Trial 1 finished with value: -0.5086415289210132 and parameters: {'lag': 1, 'normalization_choice': 3, 'window': 17}. Best is trial 0 with value: -0.429840122851624.
# [I 2023-07-02 17:36:40,590] Trial 2 finished with value: -0.3241712822866099 and parameters: {'lag': 4, 'normalization_choice': 4, 'window': 9}. Best is trial 2 with value: -0.3241712822866099.

# %%
study.trials_dataframe()["params_window"].max()
# Out:
# 25

# %%
plot_pnl(metrics["pnl_series"])

# %%
signal
# Out:
#                           BTC       ETH       BCH       XRP       EOS  \
# timestamp
# 2019-09-08 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-09 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-10 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-11 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-12 02:00:00       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2022-09-19 02:00:00  0.507127 -0.714133  0.468848  2.864510  0.329623
# 2022-09-20 02:00:00  0.246203 -0.582295  0.048529  3.305658  0.124234
# 2022-09-21 02:00:00 -0.239408 -0.711487  0.397789  3.254768  0.669365
# 2022-09-22 02:00:00 -0.278447 -0.878337  0.225419  3.113771  0.026244
# 2022-09-23 02:00:00 -0.064737 -0.957055  0.392659  3.253576 -0.587885
#
#                           LTC       TRX       ETC      LINK       XLM  ...  \
# timestamp                                                              ...
# 2019-09-08 02:00:00       NaN       NaN       NaN       NaN       NaN  ...
# 2019-09-09 02:00:00       NaN       NaN       NaN       NaN       NaN  ...
# 2019-09-10 02:00:00       NaN       NaN       NaN       NaN       NaN  ...
# 2019-09-11 02:00:00       NaN       NaN       NaN       NaN       NaN  ...
# 2019-09-12 02:00:00       NaN       NaN       NaN       NaN       NaN  ...
# ...                       ...       ...       ...       ...       ...  ...
# 
# 2019-09-08 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-09 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-10 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-11 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-12 02:00:00       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2022-09-19 02:00:00 -0.006880  0.050987  0.026821  0.006741 -0.003830
# 2022-09-20 02:00:00 -0.004364  0.044403  0.022758  0.006242 -0.000244
# 2022-09-21 02:00:00 -0.005437  0.032817  0.017760  0.004728 -0.001050
# 2022-09-22 02:00:00 -0.001508  0.048253  0.021757  0.002861 -0.003757
# 2022-09-23 02:00:00 -0.007447  0.032769  0.006668  0.003624  0.001217
#
#                          COTI       CHR      MANA     ALICE      HBAR
# timestamp
# 2019-09-08 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-09 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-10 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-11 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2019-09-12 02:00:00       NaN       NaN       NaN       NaN       NaN
# ...                       ...       ...       ...       ...       ...
# 2022-09-19 02:00:00  0.016083 -0.009771 -0.007387 -0.015769  0.002946
# 2022-09-20 02:00:00  0.020233 -0.002966 -0.001517 -0.019165  0.003579
# 2022-09-21 02:00:00  0.026223 -0.009579 -0.004601 -0.017973  0.001683
# 2022-09-22 02:00:00  0.034076 -0.009576 -0.007371 -0.023224  0.003497
# 2022-09-23 02:00:00  0.025895 -0.010218 -0.005413 -0.019157  0.003126
#
# [1112 rows x 89 columns]

# %%
signal.tail()
# Out:
#                           BTC       ETH       BCH       XRP       EOS  \
# timestamp
# 2022-09-19 02:00:00  0.507127 -0.714133  0.468848  2.864510  0.329623
# 2022-09-20 02:00:00  0.246203 -0.582295  0.048529  3.305658  0.124234
# 2022-09-21 02:00:00 -0.239408 -0.711487  0.397789  3.254768  0.669365
# 2022-09-22 02:00:00 -0.278447 -0.878337  0.225419  3.113771  0.026244
# 2022-09-23 02:00:00 -0.064737 -0.957055  0.392659  3.253576 -0.587885
#
#                           LTC       TRX       ETC      LINK       XLM  ...  \
# timestamp                                                              ...
# 2022-09-19 02:00:00  0.299971  0.535790  0.072637  2.399538  1.784134  ...
# 2022-09-20 02:00:00 -0.059928 -0.152453 -0.042528  1.412745  2.262579  ...
# 2022-09-21 02:00:00  0.014299 -0.169693 -0.142194  0.695519  3.147699  ...
# 2022-09-22 02:00:00  0.019882 -0.183597 -0.169513  0.647647  2.159719  ...
# 2022-09-23 02:00:00 -0.126457 -0.425989 -0.860361  0.482974  2.552653  ...
#
#                          UNFI      REEF       RVN       SFP       XEM  \
# timestamp
# 2022-09-19 02:00:00 -0.435230  3.225582  1.696775  0.426483 -0.242309
# 2022-09-20 02:00:00 -0.260536  2.650969  1.358672  0.372653 -0.014576
# 2022-09-21 02:00:00 -0.334211  2.017163  1.091679  0.290627 -0.064564
# 2022-09-22 02:00:00 -0.089291  2.857977  1.288619  0.169424 -0.222503
# 2022-09-23 02:00:00 -0.442482  1.947021  0.396170  0.215312  0.072295
#
#                          COTI       CHR      MANA     ALICE      HBAR
# timestamp
# 2022-09-19 02:00:00  1.017475 -0.618136 -0.467327 -0.997609  0.186399
# 2022-09-20 02:00:00  1.207932 -0.177102 -0.090584 -1.144191  0.213691
# 2022-09-21 02:00:00  1.611859 -0.588829 -0.282817 -1.104746  0.103424
# 2022-09-22 02:00:00  2.018266 -0.567198 -0.436572 -1.375525  0.207097
# 2022-09-23 02:00:00  1.538561 -0.607113 -0.321617 -1.138239  0.185716
#
# [5 rows x 89 columns]
